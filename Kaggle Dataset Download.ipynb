# %%
# !pip install opendatasets
import opendatasets as od

# %%
od.download("https://www.kaggle.com/competitions/favorita-grocery-sales-forecasting/data?select=transactions.csv.7z",force=True)

# %%
#{"username":"mirnalinigunaraj17","key":"462d2a6e056e780314451ad300e38bff"}
