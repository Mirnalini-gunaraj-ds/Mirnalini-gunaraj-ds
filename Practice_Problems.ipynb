# %%
li = ['Gratefulness','Blissful','wow','nature','world','is','heaven','Lovely']
n = 9
fil =  list(filter(lambda i : (len(i)>n), li))
print(fil)
# Out:
# ['Gratefulness']

# %%
li = [6,4,3,7,86,78]
for i in li:
    sum1 = 0
    sum1 = sum1 + i
print(sum1)
# Out:
# 78

# %%
while True:
    try:
        a = int(input("Please enter a variable"))
        b = int(input("Please enter another one"))
        c = a/b
        print(c)
        break
    except:
        print("Inputs are not correct")
        a = input("Please  variable")
        continue
# Out:
# Please enter a variableh
# Inputs are not correct
# Please  variable34
# Please enter a variable43
# Please enter another one23
# 1.8695652173913044

# %%
a = ['abbc','mim','abygya','j','ojshso']
count = 0
for i in a:
    if (len(i) > 2) :
        if [i[0] == i[-1]]:
            print(i)
            count += 1
print(count)
# Out:
# abbc
# mim
# abygya
# ojshso
# 4

# %%
a = ['ac','mi','abygya','jnahaj','ojshso']
count = 0
for i in a:
    if len(i) > 2 :
        if (i[0] == i[-1]) :
            count = count + 1
print(count)
# Out:
# 3

# %%
lis = [10,20,30,20,10,50,60,40,80,50,40,999999999,233333333,20,10]
ans = set(lis)
print(ans)
# Out:
# {40, 10, 80, 50, 20, 233333333, 60, 30, 999999999}

# %%
list1 = [{},{}]
count = 0
leng = len(list1)
for i in list1:
    if i == {}:
        count += 1
if count == leng:
    print("Empty")
else:
    print("Not empty")
# Out:
# Empty

# %%
list1 = [{},{},[]]
print(all(not i for i in list1))
# Out:
# True

# %%
li1 = [1,2,3]
import itertools as s
print(s.count())
# Out:
# count(0)

# %% [raw]
# 😊😊List - Sort
# 😊😊List - Duplicates remove
# 😊😊nested list - sort
# String matching
# 😊😊dict - duplicates remove

# %%
num = {'c':1,'b':2,'a':3}
for i in sorted(num) :
    print(i , ':' ,num[i])
# Out:
# a : 3
# b : 2
# c : 1

# %%
# remove duplicates in list
zist = [89,45,3,6,2,6,23,89,45,1,1,1,1]
zrt = []
zrt.append(zist[0])
for i in zist:
    if i not in zrt:
        zrt.append(i)
    else:
        continue
print(zrt)
# Out:
# [89, 45, 3, 6, 2, 23, 1]

# %%
z1 = [34,78,4,8,99,23,9,23]
z2 = list(set(z1))
for i in range(0,len(z2)):
    for j in range(i+1,len(z2)):
        if (z2[i] > z2[j]):
            temp = z2[i]
            z2[i] = z2[j]
            z2[j] = temp
print(z2)
# Out:
# [4, 8, 9, 23, 34, 78, 99]

# %%
z3 = [[110,120],[240],[330,456,425],[310,220],[133],[240]]
import itertools
z3.sort()
#print(z3)

new = list(z3 for z3,_ in itertools.groupby(z3))
print(new)
# Out:
# [[110, 120], [133], [240], [310, 220], [330, 456, 425]]

# %%
dup = {'name':'mirna'},{'age':27},{'Profession':'Data scientist'},{'age':27}
dup_new = [val for key,val in enumerate(dup) if val not in dup[key+1:]]
print(dup_new)
# Out:
# [{'name': 'mirna'}, {'Profession': 'Data scientist'}, {'age': 27}]

# %%
dup1 = {'a':1,'b':2}
dup1.keys()
# Out:
# dict_keys(['a', 'b'])

# %%
main = "abcdcdc"
#print(l1)
l1 = len(main)
sub = "cdc"
l2 = len(sub)
#print(    l2)
count = 0
for i in range(l1):
    if (main[i:l2+i]) == sub :
        #print(main[i:l2+i])
        count = count + 1
print(count)
# Out:
# 2

# %%
ans = [word for word in str_new1 if word == word[::-1]] 
print(ans)
# Out:
# {'this', 'in', 'long', 'time', 'didn’t', 'laugh', 'so', 'is', 'gag', 'much', 'Lol', 'I', 'a'}
# ['gag', 'I', 'a']

# %%
strng = "Lol, this is a MIMIM gag, I didn’t laugh so much in a long time"
str_new = strng.replace(",",' ' )
str_new1 = str_new.lower()
str_new1 =set(str_new1.split(" "))
print(str_new1)
ans = [word for word in str_new1 if word == word[::-1] and word != '' and len(word)!=1] 
print(ans)
# Out:
# {'', 'is', 'so', 'i', 'long', 'gag', 'didn’t', 'in', 'mimim', 'time', 'this', 'a', 'laugh', 'lol', 'much'}
# ['gag', 'mimim', 'lol']

# %%
#for i in range(1,51):
 #       if (i%2) == 0 and (i%3) != 0:
  #          print(i,"Fizz")
   #     elif (i%3) == 0 and (i%2) != 0: 
    #        print(i,"Buzz")
     #   elif (i%2) == 0 and (i%3) == 0:
      #      print(i," FizzBizz")

# %%
s = "this is just a wonder, wonder why do I have this in mind"
s1 =list(s.split(" "))
lst2 = []
lst2.append(s1[0])
print(s1)
for i in s1:
    if i not in s1:
        lst2.append(s1[i])
print(lst2)
# Out:
# ['this', 'is', 'just', 'a', 'wonder,', 'wonder', 'why', 'do', 'I', 'have', 'this', 'in', 'mind']
# ['this']

# %%
def fib(n):
    if n == 0:
        return 0
    elif n == 1:
        return 1
    else:
        return fib(n-1) + fib(n-2)
fib(7)
# Out:
# 13

# %%
len('mi  rna')
# Out:
# 7

# %%
list1 = ["M", "na", "i", "Ke"] 
list2 = ["y", "me", "s", "lly"]
li = [i + j for i,j in zip(list1,list2)]
print(li)
print(list(zip(list1,list2)))
# Out:
# ['My', 'name', 'is', 'Kelly']
# [('M', 'y'), ('na', 'me'), ('i', 's'), ('Ke', 'lly')]

# %%
list1 = ["Hello ", "take "]
list2 = ["Dear", "Sir"]
li3 = [i+j for i in list1 for j in list2]
print(li3)
# Out:
# ['Hello Dear', 'Hello Sir', 'take Dear', 'take Sir']

# %%
list1 = [10, 20, 30, 40]
list2 = [100, 200, 300, 400]
for i,j in zip(list1,list2[::-1]):
    print(i,j)
# Out:
# 10 400
# 20 300
# 30 200
# 40 100

# %%
list1 = [10, 20, [300, 400, [5000, 6000], 500], 30, 40]
list1[2][2].append(7000)
print(list1)
# Out:
# [10, 20, [300, 400, [5000, 6000, 7000], 500], 30, 40]

# %%
list1 = ["a", "b", ["c", ["d", "e", ["f", "g"], "k"], "l"], "m", "n"]
li = ['h','i','j']
list1[2][1][2].extend(li)
print(list1)
# Out:
# ['a', 'b', ['c', ['d', 'e', ['f', 'g', 'h', 'i', 'j'], 'k'], 'l'], 'm', 'n']

# %%
list1 = [20,5, 20, 15, 20, 25, 50, 20]
for i in list1:
    if i == 20:
        list1.remove(i)
print(list1)
# Out:
# [5, 15, 25, 50]

# %%
keys = ['Ten', 'Twenty', 'Thirty']
values = [10, 20, 30]
print(dict(zip(keys,values)))
# Out:
# {'Ten': 10, 'Twenty': 20, 'Thirty': 30}

# %%
d1 = {'Ten': 10, 'Twenty': 20, 'Thirty': 30}
d2 = {'Thirty': 30, 'Fourty': 40, 'Fifty': 50}
print(dict(d2,**d1))
# Out:
# {'Thirty': 30, 'Fourty': 40, 'Fifty': 50, 'Ten': 10, 'Twenty': 20}

# %%
sampleDict = { 
   "class":{ 
      "student":{ 
         "name":"Mike",
         "marks":{ 
            "physics":70,
            "history":80
         }
      }
   }
}
a = sampleDict['class']['student']['marks']['history']
print(a)
# Out:
# 80

# %%
employees = ['Kelly', 'Emma', 'John']
defaults = {"designation": 'Application Developer', "salary": 8000}

print(dict.fromkeys(employees,defaults))
# Out:
# {'Kelly': {'designation': 'Application Developer', 'salary': 8000}, 'Emma': {'designation': 'Application Developer', 'salary': 8000}, 'John': {'designation': 'Application Developer', 'salary': 8000}}

# %%
sampleDict = {
  "name": "Kelly",
  "age":25,
  "salary": 8000,
  "city": "New york"
 }
keys = ["name", "salary"]
new = { i : sampleDict[i] for i in keys}
print(new)
# Out:
# {'name': 'Kelly', 'salary': 8000}

# %%
sampleDict = {
  "name": "Kelly",
  "age":25,
  "salary": 8000,
  "city": "New york"
 }
keys = ["name", "salary"]
new = { i : sampleDict[i] for i in sampleDict if i not in keys}
print(new)
# Out:
# {'age': 25, 'city': 'New york'}

# %%
sampleDict = {'a': 100, 'b': 200, 'c': 300}
sampleDict['d'] = sampleDict.pop('c')
print(sampleDict)
# Out:
# {'a': 100, 'b': 200, 'd': 300}

# %%
sampleSet = {"Yellow", "Orange", "Black"}
sampleList = ["Blue", "Green", "Red"]
print(set.union(sampleSet,sampleList))
sampleSet.update(sampleList)
print(sampleSet)
# Out:
# {'Black', 'Orange', 'Green', 'Red', 'Blue', 'Yellow'}
# {'Black', 'Orange', 'Green', 'Red', 'Blue', 'Yellow'}

# %%
set1 = {10, 20, 30, 40, 50}
set2 = {30, 40, 50, 60, 70}
set3 = set1.intersection(set2)
print(set1)
print(set2)
print(set3)
set4 = set1.union(set2)
print(set4)
# Out:
# {40, 10, 50, 20, 30}
# {70, 40, 50, 60, 30}
# {40, 50, 30}
# {70, 40, 10, 50, 20, 60, 30}

# %%
set1 = {10, 20, 30, 40, 50}
set2 = {i for i in set1 if i >30}
print(set2)
set1.difference_update({10,20,30})
print(set1)
# Out:
# {40, 50}
# {40, 50}

# %%
set1 = {10, 20, 30, 40, 50}
set2 = {30, 40, 50, 60, 70}

print(set1.symmetric_difference(set2))
print(set1.union(set2))
# Out:
# {20, 70, 10, 60}
# {70, 40, 10, 50, 20, 60, 30}

# %%
aTuple = (10, 20, 30, 40, 50)
aTuple[::-1]
aTuple = ("Orange", [10, 20, 30], (5, 15, 25))
aTuple[1][1]
# Out:
# 20

# %%
aTuple = (50, )
bTuple = (50, )
type(aTuple)
type(bTuple)
# Out:
# tuple

# %%
aTuple = (10, 20, 30, 40)
for i in aTuple:
    print(i)
# Out:
# 10
# 20
# 30
# 40

# %%
t1 = (99, 88)
t2 = (11, 22)
t1,t2 = t2,t1
print(t1)
print(t2)
# Out:
# (11, 22)
# (99, 88)
