# %%
import pandas as pd
lf = pd.read_csv('https://raw.githubusercontent.com/jackiekazil/data-wrangling/master/data/chp3/data-text.csv')
lf
# Out:
#                                             Indicator PUBLISH STATES  Year  \
# 0                    Life expectancy at birth (years)      Published  1990
# 1                    Life expectancy at birth (years)      Published  2000
# 2                   Life expectancy at age 60 (years)      Published  2012
# 3                   Life expectancy at age 60 (years)      Published  2000
# 4                    Life expectancy at birth (years)      Published  2012
# 5                    Life expectancy at birth (years)      Published  2000
# 6                   Life expectancy at age 60 (years)      Published  1990
# 7                   Life expectancy at age 60 (years)      Published  2012
# 8                    Life expectancy at birth (years)      Published  2012
# 9                    Life expectancy at birth (years)      Published  2000
# 10                   Life expectancy at birth (years)      Published  2012
# ...

# %%
lf.info()
lf.dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4656 entries, 0 to 4655
# Data columns (total 12 columns):
# Indicator                  4656 non-null object
# PUBLISH STATES             4656 non-null object
# Year                       4656 non-null int64
# WHO region                 4656 non-null object
# World Bank income group    4656 non-null object
# Country                    4656 non-null object
# Sex                        4656 non-null object
# Display Value              4656 non-null int64
# Numeric                    4656 non-null float64
# Low                        0 non-null float64
# High                       0 non-null float64
# Comments                   0 non-null float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 436.6+ KB
# Indicator                   object
# PUBLISH STATES              object
# Year                         int64
# WHO region                  object
# World Bank income group     object
# Country                     object
# ...

# %%
fl = pd.read_csv('https://raw.githubusercontent.com/kjam/data-wrangling-pycon/master/data/berlin_weather_oldest.csv')
fl
# Out:
#                   STATION         STATION_NAME      DATE  PRCP  SNWD  SNOW  \
# 0       GHCND:GME00111445  BERLIN TEMPELHOF GM  19310101    46 -9999 -9999
# 1       GHCND:GME00111445  BERLIN TEMPELHOF GM  19310102   107 -9999 -9999
# 2       GHCND:GME00111445  BERLIN TEMPELHOF GM  19310103 -9999 -9999 -9999
# 3       GHCND:GME00111445  BERLIN TEMPELHOF GM  19310105    13 -9999 -9999
# 4       GHCND:GME00111445  BERLIN TEMPELHOF GM  19310106 -9999 -9999 -9999
# 5       GHCND:GME00111445  BERLIN TEMPELHOF GM  19310107    10 -9999 -9999
# 6       GHCND:GME00111445  BERLIN TEMPELHOF GM  19310108    13 -9999 -9999
# 7       GHCND:GME00111445  BERLIN TEMPELHOF GM  19310109    10 -9999 -9999
# 8       GHCND:GME00111445  BERLIN TEMPELHOF GM  19310110 -9999 -9999 -9999
# 9       GHCND:GME00111445  BERLIN TEMPELHOF GM  19310112 -9999 -9999 -9999
# 10      GHCND:GME00111445  BERLIN TEMPELHOF GM  19310113    13 -9999 -9999
# ...

# %%
fl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117208 entries, 0 to 117207
# Data columns (total 21 columns):
# STATION         117208 non-null object
# STATION_NAME    117208 non-null object
# DATE            117208 non-null int64
# PRCP            117208 non-null int64
# SNWD            117208 non-null int64
# SNOW            117208 non-null int64
# TMAX            117208 non-null int64
# TMIN            117208 non-null int64
# WDFG            117208 non-null int64
# PGTM            117208 non-null int64
# WSFG            117208 non-null int64
# WT09            117208 non-null int64
# WT07            117208 non-null int64
# WT01            117208 non-null int64
# WT06            117208 non-null int64
# WT05            117208 non-null int64
# WT04            117208 non-null int64
# WT16            117208 non-null int64
# WT08            117208 non-null int64
# WT18            117208 non-null int64
# WT03            117208 non-null int64
# dtypes: int64(19), object(2)
# ...

# %%
a = [lf,fl]
lf.index.values
fl.index.values
# Out:
# array([     0,      1,      2, ..., 117205, 117206, 117207], dtype=int64)

# %%
lf.rename(columns = {'Indicator':'Indicator_id'},inplace=True)
#lf.drop(columns='indicator_id',inplace=True)

# %%
lf
# Out:
#                                          Indicator_id PUBLISH STATES  Year  \
# 0                    Life expectancy at birth (years)      Published  1990
# 1                    Life expectancy at birth (years)      Published  2000
# 2                   Life expectancy at age 60 (years)      Published  2012
# 3                   Life expectancy at age 60 (years)      Published  2000
# 4                    Life expectancy at birth (years)      Published  2012
# 5                    Life expectancy at birth (years)      Published  2000
# 6                   Life expectancy at age 60 (years)      Published  1990
# 7                   Life expectancy at age 60 (years)      Published  2012
# 8                    Life expectancy at birth (years)      Published  2012
# 9                    Life expectancy at birth (years)      Published  2000
# 10                   Life expectancy at birth (years)      Published  2012
# ...

# %%
lf.rename(columns = {'Display Value':'Disp_Val','World Bank income group' : 'Income group'},inplace=True)
lf
# Out:
#                                          Indicator_id PUBLISH STATES  Year  \
# 0                    Life expectancy at birth (years)      Published  1990
# 1                    Life expectancy at birth (years)      Published  2000
# 2                   Life expectancy at age 60 (years)      Published  2012
# 3                   Life expectancy at age 60 (years)      Published  2000
# 4                    Life expectancy at birth (years)      Published  2012
# 5                    Life expectancy at birth (years)      Published  2000
# 6                   Life expectancy at age 60 (years)      Published  1990
# 7                   Life expectancy at age 60 (years)      Published  2012
# 8                    Life expectancy at birth (years)      Published  2012
# 9                    Life expectancy at birth (years)      Published  2000
# 10                   Life expectancy at birth (years)      Published  2012
# ...

# %%
lf = lf.sort_values(['Numeric'],ascending=[True])
type(fl)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-89-fda6da63f5c2> in <module>()
# ----> 1 lf = lf.sort_values(['Numeric'],ascending=[True])
#       2 type(fl)
#
# AttributeError: 'NoneType' object has no attribute 'sort_values'

# %%
fl.head()
# Out:
#              STATION         STATION_NAME      DATE  PRCP  SNWD  SNOW  TMAX  \
# 0  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310101    46 -9999 -9999 -9999
# 1  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310102   107 -9999 -9999    50
# 2  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310103 -9999 -9999 -9999    28
# 3  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310105    13 -9999 -9999    39
# 4  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310106 -9999 -9999 -9999     0
#
#    TMIN  WDFG  PGTM  ...   WT09  WT07  WT01  WT06  WT05  WT04  WT16  WT08  \
# 0   -11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 1    11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 2    11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 3    11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 4   -22 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
#
#    WT18  WT03
# 0 -9999 -9999
# 1 -9999 -9999
# 2 -9999 -9999
# ...

# %%
fl = fl.sort_values(by = ['STATION_NAME','DATE'] , ascending=[True,False])
fl.tail()
# Out:
#                   STATION  STATION_NAME      DATE  PRCP  SNWD  SNOW  TMAX  \
# 111681  GHCND:GMW00035104  TEMPELHOF GM  19490105     0     0     0    44
# 111680  GHCND:GMW00035104  TEMPELHOF GM  19490104     0     0     0    39
# 111679  GHCND:GMW00035104  TEMPELHOF GM  19490103    91 -9999     0    56
# 111678  GHCND:GMW00035104  TEMPELHOF GM  19490102     0     0     0    44
# 111677  GHCND:GMW00035104  TEMPELHOF GM  19490101     0     0     0    50
#
#         TMIN  WDFG  PGTM  ...   WT09  WT07  WT01  WT06  WT05  WT04  WT16  \
# 111681    -6 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 111680     6 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 111679    11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999     1
# 111678    17 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 111677     6 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999     1
#
#         WT08  WT18  WT03
# 111681     1 -9999 -9999
# 111680     1     1 -9999
# ...

# %%
temp_var = fl['STATION_NAME']
fl.insert(0,'STATION_NAM',temp_var)

# %%
fl.drop(columns= 'STATION_NAME',inplace= True)

# %%
fl
# Out:
#              STATION_NAM            STATION      DATE  PRCP  SNWD  SNOW  TMAX  \
# 59208   BERLIN DAHLEM GM  GHCND:GM000003319  20000101    24 -9999 -9999    23
# 59207   BERLIN DAHLEM GM  GHCND:GM000003319  19991231     0 -9999 -9999    35
# 59206   BERLIN DAHLEM GM  GHCND:GM000003319  19991230    16 -9999 -9999    26
# 59205   BERLIN DAHLEM GM  GHCND:GM000003319  19991229     0 -9999 -9999    22
# 59204   BERLIN DAHLEM GM  GHCND:GM000003319  19991228     0 -9999 -9999    20
# 59203   BERLIN DAHLEM GM  GHCND:GM000003319  19991227     0 -9999 -9999    21
# 59202   BERLIN DAHLEM GM  GHCND:GM000003319  19991226    84 -9999 -9999    42
# 59201   BERLIN DAHLEM GM  GHCND:GM000003319  19991225    34 -9999 -9999    67
# 59200   BERLIN DAHLEM GM  GHCND:GM000003319  19991224    47 -9999 -9999    30
# 59199   BERLIN DAHLEM GM  GHCND:GM000003319  19991223    25 -9999 -9999     2
# 59198   BERLIN DAHLEM GM  GHCND:GM000003319  19991222     0 -9999 -9999     4
# ...

# %%
fl.STATION_NAM.values
# Out:
# array(['BERLIN DAHLEM GM', 'BERLIN DAHLEM GM', 'BERLIN DAHLEM GM', ...,
#        'TEMPELHOF GM', 'TEMPELHOF GM', 'TEMPELHOF GM'], dtype=object)

# %%
bad = fl.index.isin(['11','24','37'])
bad.size
# Out:
# 117208

# %%
fl[~bad]
# Out:
#              STATION_NAM            STATION      DATE  PRCP  SNWD  SNOW  TMAX  \
# 59208   BERLIN DAHLEM GM  GHCND:GM000003319  20000101    24 -9999 -9999    23
# 59207   BERLIN DAHLEM GM  GHCND:GM000003319  19991231     0 -9999 -9999    35
# 59206   BERLIN DAHLEM GM  GHCND:GM000003319  19991230    16 -9999 -9999    26
# 59205   BERLIN DAHLEM GM  GHCND:GM000003319  19991229     0 -9999 -9999    22
# 59204   BERLIN DAHLEM GM  GHCND:GM000003319  19991228     0 -9999 -9999    20
# 59203   BERLIN DAHLEM GM  GHCND:GM000003319  19991227     0 -9999 -9999    21
# 59202   BERLIN DAHLEM GM  GHCND:GM000003319  19991226    84 -9999 -9999    42
# 59201   BERLIN DAHLEM GM  GHCND:GM000003319  19991225    34 -9999 -9999    67
# 59200   BERLIN DAHLEM GM  GHCND:GM000003319  19991224    47 -9999 -9999    30
# 59199   BERLIN DAHLEM GM  GHCND:GM000003319  19991223    25 -9999 -9999     2
# 59198   BERLIN DAHLEM GM  GHCND:GM000003319  19991222     0 -9999 -9999     4
# ...

# %%
import pandas as pd
users = pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/users.csv')
#sessions = pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/session1s.csv')
products =pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/products.csv')
transactions =pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/transactions.csv')

# %%
jo = transactions.merge(users,left_on='TransactionID',right_on='UserID',how='left')
jo
# Out:
#    TransactionID TransactionDate  UserID_x  ProductID  Quantity  UserID_y  \
# 0              1      2010-08-21       7.0          2         1       1.0
# 1              2      2011-05-26       3.0          4         1       2.0
# 2              3      2011-06-16       3.0          3         1       3.0
# 3              4      2012-08-26       1.0          2         3       4.0
# 4              5      2013-06-06       2.0          4         1       5.0
# 5              6      2013-12-23       2.0          5         6       NaN
# 6              7      2013-12-30       3.0          4         1       NaN
# 7              8      2014-04-24       NaN          2         3       NaN
# 8              9      2015-04-24       7.0          4         3       NaN
# 9             10      2016-05-08       3.0          4         4       NaN
#
#        User  Gender  Registered   Cancelled
# 0   Charles    male  2012-12-21         NaN
# 1     Pedro    male  2010-08-01  2010-08-08
# ...

# %%
users.head()
# Out:
#    UserID      User  Gender  Registered   Cancelled
# 0       1   Charles    male  2012-12-21         NaN
# 1       2     Pedro    male  2010-08-01  2010-08-08
# 2       3  Caroline  female  2012-10-23  2016-06-07
# 3       4   Brielle  female  2013-07-17         NaN
# 4       5  Benjamin    male  2010-11-25         NaN

# %%
transactions.head()
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity
# 0              1      2010-08-21     7.0          2         1
# 1              2      2011-05-26     3.0          4         1
# 2              3      2011-06-16     3.0          3         1
# 3              4      2012-08-26     1.0          2         3
# 4              5      2013-06-06     2.0          4         1

# %%
j1 = transactions.merge(users,left_on='UserID',right_on='UserID',how='inner')
j1
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0              2      2011-05-26     3.0          4         1  Caroline
# 1              3      2011-06-16     3.0          3         1  Caroline
# 2              7      2013-12-30     3.0          4         1  Caroline
# 3             10      2016-05-08     3.0          4         4  Caroline
# 4              4      2012-08-26     1.0          2         3   Charles
# 5              5      2013-06-06     2.0          4         1     Pedro
# 6              6      2013-12-23     2.0          5         6     Pedro
#
#    Gender  Registered   Cancelled
# 0  female  2012-10-23  2016-06-07
# 1  female  2012-10-23  2016-06-07
# 2  female  2012-10-23  2016-06-07
# 3  female  2012-10-23  2016-06-07
# 4    male  2012-12-21         NaN
# 5    male  2010-08-01  2010-08-08
# 6    male  2010-08-01  2010-08-08

# %%
transactions[~transactions.UserID.isin(j1.UserID)]
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity
# 0              1      2010-08-21     7.0          2         1
# 7              8      2014-04-24     NaN          2         3
# 8              9      2015-04-24     7.0          4         3
