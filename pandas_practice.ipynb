# %%
import pandas as pd
train = pd.read_csv("https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/fa71405126017e6a37bea592440b4bee94bf7b9e/titanic.csv",sep=',')
train.count()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
    train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
b = train.dtypes[train.dtypes == 'int64'].index
train[b].describe()
# Out:
#        PassengerId    Survived      Pclass       SibSp       Parch
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642    0.523008    0.381594
# std     257.353842    0.486592    0.836071    1.102743    0.806057
# min       1.000000    0.000000    1.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000    0.000000    0.000000
# 50%     446.000000    0.000000    3.000000    0.000000    0.000000
# 75%     668.500000    1.000000    3.000000    1.000000    0.000000
# max     891.000000    1.000000    3.000000    8.000000    6.000000

# %%
sorted(train['Name'][:1])
# Out:
# ['Braund, Mr. Owen Harris']

# %%
char_cabin = (train['Cabin']).astype(str)
new_cabin = [i[0] for i in char_cabin]
new_cabin1 = pd.Categorical(new_cabin)
train['new_cabin1'] = new_cabin1
train['new_cabin1']
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
Cabin_1
# Out:
# nan

# %%
Sex_1 = [j[0] for j in train['Sex']]
train['Sex_1'] = Sex_1
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
import numpy as np
np.where(train['Age'].isnull() == True)
# Out:
# (array([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,  45,  46,  47,
#          48,  55,  64,  65,  76,  77,  82,  87,  95, 101, 107, 109, 121,
#         126, 128, 140, 154, 158, 159, 166, 168, 176, 180, 181, 185, 186,
#         196, 198, 201, 214, 223, 229, 235, 240, 241, 250, 256, 260, 264,
#         270, 274, 277, 284, 295, 298, 300, 301, 303, 304, 306, 324, 330,
#         334, 335, 347, 351, 354, 358, 359, 364, 367, 368, 375, 384, 388,
#         409, 410, 411, 413, 415, 420, 425, 428, 431, 444, 451, 454, 457,
#         459, 464, 466, 468, 470, 475, 481, 485, 490, 495, 497, 502, 507,
#         511, 517, 522, 524, 527, 531, 533, 538, 547, 552, 557, 560, 563,
#         564, 568, 573, 578, 584, 589, 593, 596, 598, 601, 602, 611, 612,
#         613, 629, 633, 639, 643, 648, 650, 653, 656, 667, 669, 674, 680,
#         692, 697, 709, 711, 718, 727, 732, 738, 739, 740, 760, 766, 768,
#         773, 776, 778, 783, 790, 792, 793, 815, 825, 826, 828, 832, 837,
# ...

# %%
a = np.where(train['Fare'] == max(train['Fare']))
a
# Out:
# (array([258, 679, 737], dtype=int64),)

# %%
train.iloc[a][['Name','Age']]
# Out:
#                                    Name   Age
# 258                    Ward, Miss. Anna  35.0
# 679  Cardeza, Mr. Thomas Drake Martinez  36.0
# 737              Lesurer, Mr. Gustave J  35.0

# %%
a1 = np.where(train['Age'] == min(train['Age']))
train.iloc[a1][['Name','Cabin']]
# Out:
#                                 Name Cabin
# 803  Thomas, Master. Assad Alexander   NaN

# %%
train['conx'] = train['Age'] + train['Pclass']
train['conx']
# Out:
# 0      25.0
# 1      39.0
# 2      29.0
# 3      36.0
# 4      38.0
# 5       NaN
# 6      55.0
# 7       5.0
# 8      30.0
# 9      16.0
# 10      7.0
# 11     59.0
# 12     23.0
# 13     42.0
# 14     17.0
# 15     57.0
# 16      5.0
# 17      NaN
# 18     34.0
# 19      NaN
# 20     37.0
# 21     36.0
# 22     18.0
# 23     29.0
# 24     11.0
# 25     41.0
# 26      NaN
# 27     20.0
# 28      NaN
# 29      NaN
#        ...
# 861    23.0
# 862    49.0
# 863     NaN
# 864    26.0
# 865    44.0
# 866    29.0
# 867    32.0
# 868     NaN
# 869     7.0
# 870    29.0
# 871    48.0
# 872    34.0
# 873    50.0
# 874    30.0
# 875    18.0
# 876    23.0
# 877    22.0
# 878     NaN
# 879    57.0
# 880    27.0
# 881    36.0
# 882    25.0
# 883    30.0
# 884    28.0
# 885    42.0
# 886    29.0
# 887    20.0
# 888     NaN
# 889    27.0
# 890    35.0
# Name: conx, Length: 891, dtype: float64

# %%
li = [1,5,3]
ar = np.array(li)
se= pd.Series(ar,index=['a','b','c'])
se['a']
# Out:
# 1

# %%
pwd()
# Out:
# 'C:\\Users\\Mirnalini'

# %%
#Check whether parent dir exist
import os
path = 'C:\\Users\\Mirnalini\\Parent'
if (os.path.isdir(path) == True) :
    path = 'C:\\Users\\Mirnalini\\Parent\\Child1'
    if (os.path.isdir(path) == True) :
        print("Inside Child1")
        path = 'C:\\Users\\Mirnalini\\Parent\\Child1\\aaa.txt'
        #Reading Text File
        with open(path,'r') as f1:
            data1 = f1.read()
            print("Reading txt file 1" , data1)
        #writing Text File
        with open('aaa1.txt','w') as f11:
            f11.write(data1)
# Out:
# Inside Child1
# Reading txt file 1 a
# aa
# aaa
# aaaa
# aaaaa

# %%
#Reading Word document
import docx
path = 'C:\\Users\\Mirnalini\\Parent\\Child1\\Aa.docx'
data1 = docx.Document(path)
for i in data1.paragraphs:
    a = i.text
    
      
#writing word document
data2 = docx.Document()
data2.add_paragraph(a)
data2.save('Aaaa.docx')

# %%
#Reading PDF
import PyPDF2 as p
path = 'C:\\Users\\Mirnalini\\Parent\\Child1\\a.pdf'
#pdf obj
pdob = open(path,'rb')
#read obj
read = p.PdfFileReader(pdob)
#page obj
pg = read.getPage(0)
#access data
print(pg.extractText())


#writing PDF
writ = p.PdfFileWriter()
writ.addPage(pg)
pdob2 = open('aa.pdf','wb')
writ.write(pdob2)
# Out:
# ContentPart 1: Introduction
# Part 2: 5-Step Action Plan
# Part 3: Eating Schedule
# Part 4: Meal Plans

# %%
import pandas as pd
from numpy.random import randn
import random
random.seed(10)
data = randn(5,4)
#data
rw = [1,2,3,4,5]
col= ['A','B','C','D']
df = pd.DataFrame(data,index=rw,columns=col)
df
# Out:
#           A         B         C         D
# 1  1.371992 -1.717189 -0.929011  0.229043
# 2 -0.210539  1.300182 -1.219788  1.791272
# 3 -0.675609 -0.421228 -0.636617  1.982388
# 4  0.120793 -0.545527 -0.577896  1.423354
# 5  0.564386  1.128747 -1.032969 -1.328620

# %%
df.iloc[[2]]
# Out:
#           A         B         C         D
# 3  0.035055 -0.313249 -1.443231 -0.172783

# %%
df[(df['A']<0.03) | (df['B']<1.7) ]
# Out:
#           A         B         C         D
# 1  1.454511 -1.302205  0.610355  0.461871
# 3  0.035055 -0.313249 -1.443231 -0.172783
# 4  1.100998 -0.566706  0.595448 -0.375948
# 5 -0.435445 -0.038281 -0.132019  0.984932

# %%
df = df.reset_index(drop=True)
df
# Out:
#           A         B         C         D
# 0  1.454511 -1.302205  0.610355  0.461871
# 1  0.535363  1.793364  1.292815 -0.932804
# 2  0.035055 -0.313249 -1.443231 -0.172783
# 3  1.100998 -0.566706  0.595448 -0.375948
# 4 -0.435445 -0.038281 -0.132019  0.984932

# %%
l1= ['A','A','A','B','B','B','C','C','C']
l2 =[1,2,3,1,2,3,1,2,3]
l3 = [1,2,3,4,5,6,7,8,9]
ind = list(zip(l1,l2,l3))
ind = pd.MultiIndex.from_tuples(ind)
ind1 = pd.MultiIndex.from_tuples(ind)
indx = pd.DataFrame(data = np.round(randn(9,4)),index=ind1,columns=['one','Two','Three','Four'])
indx
# Out:
#        one  Two  Three  Four
# A 1 1 -2.0 -0.0    0.0  -1.0
#   2 2  1.0 -0.0   -1.0  -1.0
#   3 3  3.0  1.0    0.0  -0.0
# B 1 4 -1.0  1.0    0.0  -1.0
#   2 5  1.0 -1.0   -2.0   1.0
#   3 6  1.0  0.0   -1.0   1.0
# C 1 7  0.0 -1.0    1.0  -0.0
#   2 8  0.0  0.0   -1.0   0.0
#   3 9  0.0  1.0   -1.0  -1.0

# %%
import pandas as pd
df1 = pd.DataFrame({'K1':['K0','K8','K9','K5'],
                    'A1' :['A0','A8','A9','A5'],
                    'B1' :['B0','B8','B9','B5'],
                    'C1' :['C0','C8','C9','C5']
                     })
df1
# Out:
#    K1  A1  B1  C1
# 0  K0  A0  B0  C0
# 1  K8  A8  B8  C8
# 2  K9  A9  B9  C9
# 3  K5  A5  B5  C5

# %%
df2 = pd.DataFrame({'K2':['K0','K3','K1','K5'],
                    'A2' :['A0','A7','A9','A5'],
                    'B2' :['B0','B8','B9','B0'],
                    'C2' :['C1','C8','C1','C3']
                     })
df2
# Out:
#    K2  A2  B2  C2
# 0  K0  A0  B0  C1
# 1  K3  A7  B8  C8
# 2  K1  A9  B9  C1
# 3  K5  A5  B0  C3

# %%
df3 = pd.DataFrame({'K3':['K1','K3','K1','K3'],
                    'A3' :['A1','A7','A9','A3'],
                    'B3' :['B2','B7','8B','B1'],
                    'C3' :['C2','C9','C2','C4']
                     })
df3
# Out:
#    K3  A3  B3  C3
# 0  K1  A1  B2  C2
# 1  K3  A7  B7  C9
# 2  K1  A9  8B  C2
# 3  K3  A3  B1  C4

# %%
c = pd.concat([df1,df2,df3])
c
# Out:
# C:\Users\Mirnalini\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#     A1   A2   A3   B1   B2   B3   C1   C2   C3   K1   K2   K3
# 0   A0  NaN  NaN   B0  NaN  NaN   C0  NaN  NaN   K0  NaN  NaN
# 1   A8  NaN  NaN   B8  NaN  NaN   C8  NaN  NaN   K8  NaN  NaN
# 2   A9  NaN  NaN   B9  NaN  NaN   C9  NaN  NaN   K9  NaN  NaN
# 3   A5  NaN  NaN   B5  NaN  NaN   C5  NaN  NaN   K5  NaN  NaN
# 0  NaN   A0  NaN  NaN   B0  NaN  NaN   C1  NaN  NaN   K0  NaN
# 1  NaN   A7  NaN  NaN   B8  NaN  NaN   C8  NaN  NaN   K3  NaN
# 2  NaN   A9  NaN  NaN   B9  NaN  NaN   C1  NaN  NaN   K1  NaN
# 3  NaN   A5  NaN  NaN   B0  NaN  NaN   C3  NaN  NaN   K5  NaN
# ...

# %%
d = pd.merge(df1,df2,how='outer',left_on='K1', right_on='K2')
d
# Out:
#     K1   A1   B1   C1   K2   A2   B2   C2
# 0   K0   A0   B0   C0   K0   A0   B0   C1
# 1   K8   A8   B8   C8  NaN  NaN  NaN  NaN
# 2   K9   A9   B9   C9  NaN  NaN  NaN  NaN
# 3   K5   A5   B5   C5   K5   A5   B0   C3
# 4  NaN  NaN  NaN  NaN   K3   A7   B8   C8
# 5  NaN  NaN  NaN  NaN   K1   A9   B9   C1

# %%
import pandas as pd
e = pd.
e
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-86ef6fd22bbe> in <module>()
#       1 import pandas as pd
# ----> 2 e = pd.Join(df1,df2)
#       3 e
#
# AttributeError: module 'pandas' has no attribute 'Join'

# %%
import numpy as np
df['AA'] = df['A'].apply(lambda i : np.log(i))
df['BB'] = df['B'].apply(lambda i : np.square(i))
df
# Out:
#           A         B         C         D        AA        BB
# 1  1.371992 -1.717189 -0.929011  0.229043  0.316264  2.948738
# 2 -0.210539  1.300182 -1.219788  1.791272       NaN  1.690473
# 3 -0.675609 -0.421228 -0.636617  1.982388       NaN  0.177433
# 4  0.120793 -0.545527 -0.577896  1.423354 -2.113676  0.297600
# 5  0.564386  1.128747 -1.032969 -1.328620 -0.572017  1.274070

# %%
import pandas as pd
nin = pd.read_csv('https://raw.githubusercontent.com/PramodShenoy/911-Calls/master/911.csv',sep=',')
nin
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#
# ~\Anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#
# ~\Anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
#    1276
#
# ...

# %%
nin.describe()
# Out:
#                 lat           lng           zip        e          lat1
# count  99492.000000  99492.000000  86637.000000  99492.0  99492.000000
# mean      40.159526    -75.317464  19237.658298      1.0     39.984984
# std        0.094446      0.174826    345.344914      0.0      0.127587
# min       30.333596    -95.595595  17752.000000      1.0     30.000000
# 25%       40.100423    -75.392104  19038.000000      1.0     40.000000
# 50%       40.145223    -75.304667  19401.000000      1.0     40.000000
# 75%       40.229008    -75.212513  19446.000000      1.0     40.000000
# max       41.167156    -74.995041  77316.000000      1.0     41.000000

# %%
a = nin.dtypes[nin.dtypes == 'object']
a.describe()
nin.dtypes
# Out:
# lat          float64
# lng          float64
# desc          object
# zip          float64
# title         object
# timeStamp     object
# twp           object
# addr          object
# e              int64
# lat1           int64
# dtype: object

# %%
nin['lat'].apply(lambda i : int(i)) 
nin
# Out:
#              lat        lng  \
# 0      40.297876 -75.581294
# 1      40.258061 -75.264680
# 2      40.121182 -75.351975
# 3      40.116153 -75.343513
# 4      40.251492 -75.603350
# 5      40.253473 -75.283245
# 6      40.182111 -75.127795
# 7      40.217286 -75.405182
# 8      40.289027 -75.399590
# 9      40.102398 -75.291458
# 10     40.231990 -75.251891
# 11     40.084161 -75.308386
# 12     40.174131 -75.098491
# 13     40.062974 -75.135914
# 14     40.097222 -75.376195
# 15     40.223778 -75.235399
# 16     40.243258 -75.286552
# 17     40.312181 -75.574260
# 18     40.114239 -75.338508
# 19     40.209337 -75.135266
# 20     40.114239 -75.338508
# 21     40.117948 -75.209848
# 22     40.199006 -75.300058
# 23     40.143326 -75.422819
# 24     40.153268 -75.189558
# 25     40.133037 -75.408463
# 26     40.155283 -75.264230
# 27     40.028903 -75.351822
# 28     40.097222 -75.376195
# 29     40.209337 -75.135266
# ...          ...        ...
# 99462  40.274137 -75.660469
# ...

# %%
nin.groupby(by ='zip')

# %%
# %time
# Out:
# Wall time: 0 ns
