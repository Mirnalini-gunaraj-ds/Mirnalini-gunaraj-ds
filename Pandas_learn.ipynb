# %%
import numpy as np
import pandas as pd
np.set_printoptions(precision=4)

# %%
df = pd.read_csv(r'C:\Users\Mirnalini\Downloads\examples\ex1.csv',names=['aa','bb','cc','dd','ee','ff'],na_values=['NULL'])
df
# Out:
#   aa  bb  cc  dd       ee  ff
# 0  a   b   c   d  message NaN
# 1  1   2   3   4    hello NaN
# 2  5   6   7   8    world NaN
# 3  9  10  11  12      foo NaN

# %%
df1 = pd.read_csv(r'C:\Users\Mirnalini\Downloads\examples\test.tsv',sep='\t')
df1
# Out:
#         test   test test.1 test.2 test.3
# sudh    sudh   sudh   sudh   sudh   sudh
# kumar  kumar  kumar  kumar  kumar  kumar

# %%
df.tail(1)
# Out:
#    a   b   c   d message
# 2  9  10  11  12     foo

# %%
df2 = pd.read_csv(r'C:\Users\Mirnalini\Downloads\examples\csv_mindex.csv',index_col=['key1','key2'])
df2
# Out:
#            value1  value2
# key1 key2
# one  a          1       2
#      b          3       4
#      c          5       6
#      d          7       8
# two  a          9      10
#      b         11      12
#      c         13      14
#      d         15      16

# %%
df3 = pd.read_csv(r'C:\Users\Mirnalini\Downloads\examples\ex4.csv',skiprows=[0,2,3])
df3
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
import pandas as pd
df4 = pd.read_excel(r'C:\Users\Mirnalini\Downloads\examples\mi.xlsx',sheet_name='Sheet2',header=None,names=['a','b','c','d','e'])
df4
# Out:
#         a    b      c    d    e
# 0  edrejh  fer  ujhuj    j   jh
# 1      45    6    NaN    6    6
# 2      56    6    NaN    6    6
# 3      77  NaN    NaN    6   24
# 4     NaN    6    NaN  NaN  NaN

# %%
df5 = pd.read_html('https://www.basketball-reference.com/',skiprows=['1','2'])
len(df5)
df5[0].tail()
# Out:
#           East Unnamed: 1 Unnamed: 2   W   L
# 10  CHI x (11)          F          $  22  43
# 11  NYK x (12)          F          $  21  45
# 12  DET x (13)          F          $  20  46
# 13  ATL x (14)          F          $  20  47
# 14  CLE x (15)          F          $  19  46

# %%
df5[0].columns
# Out:
# Index(['East', 'Unnamed: 1', 'Unnamed: 2', 'W', 'L'], dtype='object')

# %%
df5[0].dtypes
# Out:
# East          object
# Unnamed: 1    object
# Unnamed: 2    object
# W              int64
# L              int64
# dtype: object

# %%
dff = pd.read_csv('https://raw.githubusercontent.com/akhil12028/Bank-Marketing-data-set-analysis/master/bank-additional-full.csv',sep=';')

# %%
dff
# Out:
#        age            job   marital            education  default  housing  \
# 0       56      housemaid   married             basic.4y       no       no
# 1       57       services   married          high.school  unknown       no
# 2       37       services   married          high.school       no      yes
# 3       40         admin.   married             basic.6y       no       no
# 4       56       services   married          high.school       no       no
# 5       45       services   married             basic.9y  unknown       no
# 6       59         admin.   married  professional.course       no       no
# 7       41    blue-collar   married              unknown  unknown       no
# 8       24     technician    single  professional.course       no      yes
# 9       25       services    single          high.school       no      yes
# 10      41    blue-collar   married              unknown  unknown       no
# ...

# %%
dff.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon ...         1    999         0  nonexistent          1.1
# 1   may         mon ...         1    999         0  nonexistent          1.1
# 2   may         mon ...         1    999         0  nonexistent          1.1
# 3   may         mon ...         1    999         0  nonexistent          1.1
# 4   may         mon ...         1    999         0  nonexistent          1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# ...

# %%
dff.tail(2)
# Out:
#        age         job  marital            education default housing loan  \
# 41186   44  technician  married  professional.course      no      no   no
# 41187   74     retired  married  professional.course      no     yes   no
#
#         contact month day_of_week ...   campaign  pdays  previous  \
# 41186  cellular   nov         fri ...          1    999         0
# 41187  cellular   nov         fri ...          3    999         1
#
#           poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 41186  nonexistent         -1.1          94.767          -50.8      1.028
# 41187      failure         -1.1          94.767          -50.8      1.028
#
#        nr.employed    y
# 41186       4963.6  yes
# 41187       4963.6   no
#
# [2 rows x 21 columns]

# %%
dff['age'].dtypes
# Out:
# dtype('int64')

# %%
dff.dtypes
# Out:
# age                 int64
# job                object
# marital            object
# education          object
# default            object
# housing            object
# loan               object
# contact            object
# month              object
# day_of_week        object
# duration            int64
# campaign            int64
# pdays               int64
# previous            int64
# poutcome           object
# emp.var.rate      float64
# cons.price.idx    float64
# cons.conf.idx     float64
# euribor3m         float64
# nr.employed       float64
# y                  object
# dtype: object

# %%
dff.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
dff.skip_rows['0']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-126-fd71cbc971e6> in <module>()
# ----> 1 dff.skip_rows['0']
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'skip_rows'

# %%
dff.rename(columns={'age':'Age'})
# Out:
#        Age            job   marital            education  default  housing  \
# 0       56      housemaid   married             basic.4y       no       no
# 1       57       services   married          high.school  unknown       no
# 2       37       services   married          high.school       no      yes
# 3       40         admin.   married             basic.6y       no       no
# 4       56       services   married          high.school       no       no
# 5       45       services   married             basic.9y  unknown       no
# 6       59         admin.   married  professional.course       no       no
# 7       41    blue-collar   married              unknown  unknown       no
# 8       24     technician    single  professional.course       no      yes
# 9       25       services    single          high.school       no      yes
# 10      41    blue-collar   married              unknown  unknown       no
# ...

# %%
import pandas
pd.options.display.max_columns=10
dff
# Out:
#        age            job   marital            education  default ...   \
# 0       56      housemaid   married             basic.4y       no ...
# 1       57       services   married          high.school  unknown ...
# 2       37       services   married          high.school       no ...
# 3       40         admin.   married             basic.6y       no ...
# 4       56       services   married          high.school       no ...
# 5       45       services   married             basic.9y  unknown ...
# 6       59         admin.   married  professional.course       no ...
# 7       41    blue-collar   married              unknown  unknown ...
# 8       24     technician    single  professional.course       no ...
# 9       25       services    single          high.school       no ...
# 10      41    blue-collar   married              unknown  unknown ...
# 11      25       services    single          high.school       no ...
# ...

# %%
import pandas as pd
pd.options.display.max_columns = 10
ff = pd.read_csv('https://raw.githubusercontent.com/akhil12028/Bank-Marketing-data-set-analysis/master/bank-additional-full.csv',sep=';',chunksize=10)
ff

# %%
df5[0]
# Out:
#           East Unnamed: 1 Unnamed: 2   W   L
# 0    MIL * (1)          F          $  56  17
# 1    TOR * (2)          F          $  53  19
# 2    BOS * (3)          F          $  48  24
# 3    IND * (4)          F          $  45  28
# 4    MIA * (5)          F          $  44  29
# 5    PHI * (6)          F          $  43  30
# 6    BRK * (7)          F          $  35  37
# 7    ORL * (8)          F          $  33  40
# 8    CHO x (9)          F          $  23  42
# 9   WAS x (10)          F          $  25  47
# 10  CHI x (11)          F          $  22  43
# 11  NYK x (12)          F          $  21  45
# 12  DET x (13)          F          $  20  46
# 13  ATL x (14)          F          $  20  47
# 14  CLE x (15)          F          $  19  46

# %%
df5[0].to_csv('xyz.csv',index=False,columns=['East','W'])

# %%
dates = pd.date_range('1/1/2000',periods=7)

# %%
dates
# Out:
# DatetimeIndex(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04',
#                '2000-01-05', '2000-01-06', '2000-01-07'],
#               dtype='datetime64[ns]', freq='D')

# %%
import numpy as np
import pandas as pd
df = pd.Series(np.arange(7),index=['mir','1','e','5','5','5','9'])
type(df)
df
# Out:
# mir    0
# 1      1
# e      2
# 5      3
# 5      4
# 5      5
# 9      6
# dtype: int32

# %%
import numpy as np
import pandas as pd
df = pd.Series(np.arange(7),index=dates)
type(df)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-50731367048b> in <module>()
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 df = pd.Series(np.arange(7),index=dates)
#       4 type(df)
#       5 df
#
# NameError: name 'dates' is not defined

# %%
import csv

# %%
o = open('xyz.csv')
p = csv.reader(o)

# %%
type(p)
# Out:
# _csv.reader

# %%
for i in p:
    print(i)

# %%
l1 = [5,78,4,8,9,0]    
l2 = [1,8,4,3,9]
list(zip(l1,l2))
# Out:
# [(5, 1), (78, 8), (4, 4), (8, 3), (9, 9)]

# %%
s = pd.read_json(r'C:\Users\Mirnalini\Downloads\examples\example.json')

# %%
s
# Out:
#    a  b  c
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
import requests
resp = requests.get('https://api.github.com/repos/pandas-dev/pandas/issues')
type(resp)
# Out:
# requests.models.Response

# %%
data = resp.json()
data
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/35767',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/35767/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/35767/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/35767/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/35767',
#   'id': 680175748,
#   'node_id': 'MDU6SXNzdWU2ODAxNzU3NDg=',
#   'number': 35767,
#   'title': 'BUG: datetime ExtensionDtype do not work with DataFrame',
#   'user': {'login': 'marco-neumann-by',
#    'id': 57095103,
#    'node_id': 'MDQ6VXNlcjU3MDk1MTAz',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/57095103?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/marco-neumann-by',
#    'html_url': 'https://github.com/marco-neumann-by',
# ...

# %%
# Out:
# pandas.core.frame.DataFrame

# %%
# Out:
# Empty DataFrame
# Columns: [a, b, c, d, e, f, g]
# Index: []

# %%
    sub = pd.DataFrame(data[i]['labels'],columns=['a','b','c','d','e','f','g'])
    m1 = m1.append(sub,ignore_index=True)

# %%
m1
# Out:
#       a    b    c    d    e    f    g
# 0   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 5   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 6   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 7   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 8   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 9   NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 10  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 11  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 12  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 14  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 15  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 16  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 17  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 18  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 19  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 20  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 21  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 22  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 23  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...
