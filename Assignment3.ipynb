# %% [markdown]
# # 1.1 ) Reduce function

# %%
def myreduce(li,tot):
    for i in li:
        tot = tot + i
    return(tot)

li = [1,19,61,81,20,10]
tot = 0
print("Total is" , myreduce(li,tot))
# Out:
# Total is 192

# %% [markdown]
# # 1.2 ) Filter function

# %%
def myfilter(ls):
    for i in ls:
        if (i % 2) == 0 :
            lst.append(i)
lst = []
ls = [2,43,65,21,72,46,84]
myfilter(ls)
print(lst)
# Out:
# [2, 72, 46, 84]

# %% [markdown]
# # 2) List Comprehension

# %%
[i*j for i in 'xyz' for j in range(1,5)]
# Out:
# ['x', 'xx', 'xxx', 'xxxx', 'y', 'yy', 'yyy', 'yyyy', 'z', 'zz', 'zzz', 'zzzz']

# %%
[i*j for i in range(1,5) for j in 'xyz']
# Out:
# ['x', 'y', 'z', 'xx', 'yy', 'zz', 'xxx', 'yyy', 'zzz', 'xxxx', 'yyyy', 'zzzz']

# %%
part1 = [[j] for i in range(2,5) for j in range(i,i+3)]
print(part1)

part2 =[[i for i  in range(2+j,6+j)] for j in range(0,4)]
print(part2)

part3 = part1.append(part2)
# Out:
# [[2], [3], [4], [3], [4], [5], [4], [5], [6]]
# [[2, 3, 4, 5], [3, 4, 5, 6], [4, 5, 6, 7], [5, 6, 7, 8]]

# %%
[(j,i) for i in range(1,4) for j in range(1,4)]
# Out:
# [(1, 1), (2, 1), (3, 1), (1, 2), (2, 2), (3, 2), (1, 3), (2, 3), (3, 3)]
