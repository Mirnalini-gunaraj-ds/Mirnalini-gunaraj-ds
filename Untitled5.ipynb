# %%
import pandas as pd
nin = pd.read_csv('https://raw.githubusercontent.com/PramodShenoy/911-Calls/master/911.csv',sep=',')
nin
# Out:
#              lat        lng  \
# 0      40.297876 -75.581294
# 1      40.258061 -75.264680
# 2      40.121182 -75.351975
# 3      40.116153 -75.343513
# 4      40.251492 -75.603350
# 5      40.253473 -75.283245
# 6      40.182111 -75.127795
# 7      40.217286 -75.405182
# 8      40.289027 -75.399590
# 9      40.102398 -75.291458
# 10     40.231990 -75.251891
# 11     40.084161 -75.308386
# 12     40.174131 -75.098491
# 13     40.062974 -75.135914
# 14     40.097222 -75.376195
# 15     40.223778 -75.235399
# 16     40.243258 -75.286552
# 17     40.312181 -75.574260
# 18     40.114239 -75.338508
# 19     40.209337 -75.135266
# 20     40.114239 -75.338508
# 21     40.117948 -75.209848
# 22     40.199006 -75.300058
# 23     40.143326 -75.422819
# 24     40.153268 -75.189558
# 25     40.133037 -75.408463
# 26     40.155283 -75.264230
# 27     40.028903 -75.351822
# 28     40.097222 -75.376195
# 29     40.209337 -75.135266
# ...          ...        ...
# 99462  40.274137 -75.660469
# ...

# %%
#Numerical data describe
nin.describe()
#categorical data describe
nin.dtypes[nin.dtypes == 'object'].describe()
# Out:
# count          5
# unique         1
# top       object
# freq           5
# dtype: object

# %%
a = nin['lat'].astype('int')
nin['lat1'] = nin['lat'].apply(lambda i : int(i))
a.dtype
nin
nin['lat1'].value_counts()
# Out:
# 40    98012
# 39     1477
# 41        1
# 32        1
# 30        1
# Name: lat1, dtype: int64

# %%
a = nin.groupby('lat1')
a.first()
# Out:
#             lat        lng                                               desc  \
# lat1
# 30    30.333596 -95.595595  8931;  MONTGOMERY; Station 311; 2016-06-02 @ 1...
# 32    32.387090 -86.276106          600  ; MONTGOMERY; 2016-02-12 @ 18:44:37;
# 39    39.986770 -75.275433  LLOYD LN & DRAYTON LN;  LOWER MERION; Station ...
# 40    40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 41    41.167156 -76.874030      MAIN;  ; Station 308A; 2016-01-02 @ 13:01:30;
#
#           zip                           title            timeStamp  \
# lat1
# 30    77316.0          EMS: CARDIAC EMERGENCY  2016-06-02 13:36:01
# 32    36107.0     Traffic: DISABLED VEHICLE -  2016-02-12 18:47:01
# 39    19096.0         EMS: DIABETIC EMERGENCY  2015-12-10 20:07:01
# 40    19525.0          EMS: BACK PAINS/INJURY  2015-12-10 17:40:00
# 41    17752.0  EMS: UNKNOWN MEDICAL EMERGENCY  2016-01-02 13:06:00
#
#                twp                    addr  e
# lat1
# ...

# %%
a.size()
# Out:
# lat1
# 30        1
# 32        1
# 39     1477
# 40    98012
# 41        1
# dtype: int64

# %%
#ziplo = nin.groupby('zip')
#ziplo.size()
nin['zip'].value_counts().head(20)
# Out:
# 19401.0    6979
# 19464.0    6643
# 19403.0    4854
# 19446.0    4748
# 19406.0    3174
# 19002.0    3050
# 19468.0    2990
# 19454.0    2781
# 19090.0    2635
# 19038.0    2578
# 19046.0    2564
# 19426.0    2461
# 19428.0    2296
# 19006.0    2256
# 19462.0    2078
# 19040.0    2043
# 19438.0    1990
# 19422.0    1963
# 19027.0    1818
# 19044.0    1595
# Name: zip, dtype: int64

# %%
ziplo.size()
# Out:
# zip
# 17752.0       1
# 18036.0       2
# 18041.0     414
# 18054.0     326
# 18056.0       6
# 18070.0      54
# 18073.0     736
# 18074.0     435
# 18076.0     306
# 18092.0      14
# 18103.0       4
# 18914.0      66
# 18915.0     118
# 18927.0       2
# 18932.0      11
# 18936.0     254
# 18951.0      10
# 18960.0      34
# 18964.0    1287
# 18966.0      44
# 18969.0     672
# 18974.0     215
# 18976.0      45
# 19001.0    1514
# 19002.0    3050
# 19003.0    1094
# 19004.0    1280
# 19006.0    2256
# 19009.0      49
# 19010.0    1316
#            ...
# 19423.0       4
# 19426.0    2461
# 19428.0    2296
# 19435.0      35
# 19438.0    1990
# 19440.0    1190
# 19444.0    1008
# 19446.0    4748
# 19453.0     101
# 19454.0    2781
# 19457.0       1
# 19460.0     427
# 19462.0    2078
# 19464.0    6643
# 19465.0     458
# 19468.0    2990
# 19472.0       6
# 19473.0    1012
# 19475.0      73
# 19477.0      10
# 19490.0       1
# 19492.0      40
# 19503.0       4
# 19504.0     101
# ...

# %%
nin['timeStamp'] = pd.to_datetime(nin['timeStamp'])
import datetime 
nin['Day'] = nin.timeStamp.dt.weekday_name
nin
# Out:
#              lat        lng  \
# 0      40.297876 -75.581294
# 1      40.258061 -75.264680
# 2      40.121182 -75.351975
# 3      40.116153 -75.343513
# 4      40.251492 -75.603350
# 5      40.253473 -75.283245
# 6      40.182111 -75.127795
# 7      40.217286 -75.405182
# 8      40.289027 -75.399590
# 9      40.102398 -75.291458
# 10     40.231990 -75.251891
# 11     40.084161 -75.308386
# 12     40.174131 -75.098491
# 13     40.062974 -75.135914
# 14     40.097222 -75.376195
# 15     40.223778 -75.235399
# 16     40.243258 -75.286552
# 17     40.312181 -75.574260
# 18     40.114239 -75.338508
# 19     40.209337 -75.135266
# 20     40.114239 -75.338508
# 21     40.117948 -75.209848
# 22     40.199006 -75.300058
# 23     40.143326 -75.422819
# 24     40.153268 -75.189558
# 25     40.133037 -75.408463
# 26     40.155283 -75.264230
# 27     40.028903 -75.351822
# 28     40.097222 -75.376195
# 29     40.209337 -75.135266
# ...          ...        ...
# 99462  40.274137 -75.660469
# ...

# %%
nin['da'] = nin['timeStamp'].dt.day
nin
# Out:
#              lat        lng  \
# 0      40.297876 -75.581294
# 1      40.258061 -75.264680
# 2      40.121182 -75.351975
# 3      40.116153 -75.343513
# 4      40.251492 -75.603350
# 5      40.253473 -75.283245
# 6      40.182111 -75.127795
# 7      40.217286 -75.405182
# 8      40.289027 -75.399590
# 9      40.102398 -75.291458
# 10     40.231990 -75.251891
# 11     40.084161 -75.308386
# 12     40.174131 -75.098491
# 13     40.062974 -75.135914
# 14     40.097222 -75.376195
# 15     40.223778 -75.235399
# 16     40.243258 -75.286552
# 17     40.312181 -75.574260
# 18     40.114239 -75.338508
# 19     40.209337 -75.135266
# 20     40.114239 -75.338508
# 21     40.117948 -75.209848
# 22     40.199006 -75.300058
# 23     40.143326 -75.422819
# 24     40.153268 -75.189558
# 25     40.133037 -75.408463
# 26     40.155283 -75.264230
# 27     40.028903 -75.351822
# 28     40.097222 -75.376195
# 29     40.209337 -75.135266
# ...          ...        ...
# 99462  40.274137 -75.660469
# ...

# %%
#address =  nin[nin['addr'].astype(str).str[0] == 'A']
#address['zip']
nin[nin['addr'].astype(str).str[0] == 'A']['zip'].value_counts()
# Out:
# 19401.0    616
# 19446.0    296
# 19027.0    175
# 19406.0    165
# 19003.0    152
# 19464.0    116
# 18964.0    111
# 19403.0    106
# 19426.0     82
# 19428.0     75
# 19468.0     75
# 19012.0     63
# 19044.0     54
# 19454.0     51
# 19444.0     47
# 19096.0     45
# 18969.0     44
# 19090.0     39
# 19422.0     38
# 19038.0     37
# 19095.0     35
# 19001.0     34
# 19002.0     30
# 19438.0     30
# 19040.0     26
# 19462.0     26
# 19010.0     22
# 19440.0     20
# 19072.0     18
# 19004.0     17
#           ...
# 19009.0     12
# 19046.0     11
# 18076.0     10
# 19525.0     10
# 19473.0      9
# 19075.0      8
# 19031.0      8
# 19041.0      7
# 19460.0      5
# 19087.0      5
# 19453.0      5
# 18915.0      4
# 18041.0      4
# 18960.0      3
# 19085.0      3
# 19505.0      2
# 19034.0      2
# 19066.0      2
# 18936.0      2
# 18074.0      2
# 19504.0      2
# 19118.0      2
# 18974.0      2
# 19035.0      1
# 18914.0      1
# 18054.0      1
# 19475.0      1
# ...

# %%
nin['title']
nin['reason'] = nin['title'].apply(lambda i : i.split(':')[0])
nin['cat'] = nin['title'].apply(lambda i : i.split(':')[1])
nin['reason']
nin['cat']
# Out:
# 0                 BACK PAINS/INJURY
# 1                DIABETIC EMERGENCY
# 2                     GAS-ODOR/LEAK
# 3                 CARDIAC EMERGENCY
# 4                         DIZZINESS
# 5                       HEAD INJURY
# 6                   NAUSEA/VOMITING
# 7             RESPIRATORY EMERGENCY
# 8                  SYNCOPAL EPISODE
# 9                VEHICLE ACCIDENT -
# 10               VEHICLE ACCIDENT -
# 11               VEHICLE ACCIDENT -
# 12               VEHICLE ACCIDENT -
# 13               VEHICLE ACCIDENT -
# 14               VEHICLE ACCIDENT -
# 15               VEHICLE ACCIDENT -
# 16            RESPIRATORY EMERGENCY
# 17                        DIZZINESS
# 18                 VEHICLE ACCIDENT
# 19               DISABLED VEHICLE -
# 20               VEHICLE ACCIDENT -
# 21               DISABLED VEHICLE -
# 22                   APPLIANCE FIRE
# 23               DISABLED VEHICLE -
# 24               VEHICLE ACCIDENT -
# 25                 GENERAL WEAKNESS
# ...

# %%
nin.isnull().sum()
# Out:
# lat              0
# lng              0
# desc             0
# zip          12855
# title            0
# timeStamp        0
# twp             43
# addr           519
# e                0
# lat1             0
# reason           0
# dtype: int64

# %%
nin.isnull().count()
# Out:
# lat          99492
# lng          99492
# desc         99492
# zip          99492
# title        99492
# timeStamp    99492
# twp          99492
# addr         99492
# e            99492
# lat1         99492
# reason       99492
# dtype: int64

# %%
nin[nin['twp']=='LOWER MERION']['reason'].value_counts()
# Out:
# Traffic    3724
# EMS        3171
# Fire       1548
# Name: reason, dtype: int64

# %%
nin['twp']
# Out:
# 0              NEW HANOVER
# 1        HATFIELD TOWNSHIP
# 2               NORRISTOWN
# 3               NORRISTOWN
# 4         LOWER POTTSGROVE
# 5                 LANSDALE
# 6                  HORSHAM
# 7                 SKIPPACK
# 8            LOWER SALFORD
# 9                 PLYMOUTH
# 10              MONTGOMERY
# 11                PLYMOUTH
# 12          UPPER MORELAND
# 13              CHELTENHAM
# 14            UPPER MERION
# 15              MONTGOMERY
# 16                LANSDALE
# 17             NEW HANOVER
# 18              NORRISTOWN
# 19                 HORSHAM
# 20              NORRISTOWN
# 21              WHITEMARSH
# 22           UPPER GWYNEDD
# 23        LOWER PROVIDENCE
# 24            UPPER DUBLIN
# 25        LOWER PROVIDENCE
# 26                WHITPAIN
# 27         DELAWARE COUNTY
# 28            UPPER MERION
# 29                 HORSHAM
#                ...
# 99462      WEST POTTSGROVE
# 99463            POTTSTOWN
# 99464       UPPER MORELAND
# ...

# %%
import pandas as pd
dff = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv',sep='\t')
dff.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
dff.isnull().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
 dff1 = dff[dff['choice_description'].isnull() == True]
dff1['item_name'].value_counts()
# Out:
# Chips and Guacamole                      479
# Chips                                    211
# Bottled Water                            162
# Chips and Fresh Tomato Salsa             110
# Side of Chips                            101
# Chips and Tomatillo Red Chili Salsa       48
# Chips and Tomatillo Green Chili Salsa     43
# Chips and Tomatillo-Green Chili Salsa     31
# Chips and Roasted Chili Corn Salsa        22
# Chips and Tomatillo-Red Chili Salsa       20
# Chips and Roasted Chili-Corn Salsa        18
# Chips and Mild Fresh Tomato Salsa          1
# Name: item_name, dtype: int64

# %%
a = dff.loc[dff['item_name'] == 'Chicken Salad Bowl']
a.head()
b = dff.loc[dff['order_id'] == 20]
b
#dff['order_id']
# Out:
#     order_id  quantity            item_name  \
# 41        20         1  Chips and Guacamole
# 42        20         1         Chicken Bowl
# 43        20         1        Steak Burrito
# 44        20         1   Chicken Salad Bowl
#
#                                    choice_description  item_price do2 dol
# 41                                                NaN        4.45   4   $
# 42  [Roasted Chili Corn Salsa, [Rice, Black Beans,...       11.25   1   $
# 43  [Fresh Tomato Salsa, [Rice, Pinto Beans, Chees...       11.75   1   $
# 44  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...        8.75   8   $

# %%
a =dff.groupby(by = 'item_name')
a= a.sum()
a = a.sort_values(['quantity'],ascending=False)
a = a.head(1)
a
# Out:
#               order_id  quantity
# item_name
# Chicken Bowl    713926       761

# %%
c =dff.groupby(by = 'choice_description')
c= c.sum()
c = c.sort_values(['quantity'],ascending=False)
c.head(1)
# Out:
#                     order_id  quantity
# choice_description
# [Diet Coke]           123455       159

# %%
dff['dol'] = dff['item_price'].apply(lambda i : i[0])
dff['do2'] = dff['item_price'].apply(lambda i : i[1])
dff['do2'].astype(float)
dff['do2'].dtype
#dff = dff.drop(columns='dol',axis=1)
#dff.describe()
# Out:
# dtype('O')

# %%
#doll = lambda x : float(x[1:])
#dff.item_price = dff.item_price.apply(doll)
dff.sort_values(by='item_price',ascending=False).head(1)
# Out:
#       order_id  quantity                     item_name choice_description  \
# 3598      1443        15  Chips and Fresh Tomato Salsa                NaN
#
#       item_price do2 dol
# 3598       44.25   4   $

# %%
dff['item_price'].dtype
# Out:
# dtype('float64')

# %%
dff
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# 5            3         1                           Chicken Bowl
# 6            3         1                          Side of Chips
# 7            4         1                          Steak Burrito
# 8            4         1                       Steak Soft Tacos
# 9            5         1                          Steak Burrito
# 10           5         1                    Chips and Guacamole
# 11           6         1                   Chicken Crispy Tacos
# 12           6         1                     Chicken Soft Tacos
# 13           7         1                           Chicken Bowl
# ...

# %%
revenue = dff['item_price'] * dff['quantity']
rev = revenue.sum()                      
print("\n Revenue was: $" +str(rev))
# Out:
#  Revenue was: $39237.02

# %%
data = [dff['item_name'], dff['item_price']]
data
heade = ['NAme','Price']
dff_new = pd.concat(data,keys=heade,axis=1)
dff_new
# Out:
#                                        NAme  Price
# 0              Chips and Fresh Tomato Salsa   2.39
# 1                                      Izze   3.39
# 2                          Nantucket Nectar   3.39
# 3     Chips and Tomatillo-Green Chili Salsa   2.39
# 4                              Chicken Bowl  16.98
# 5                              Chicken Bowl  10.98
# 6                             Side of Chips   1.69
# 7                             Steak Burrito  11.75
# 8                          Steak Soft Tacos   9.25
# 9                             Steak Burrito   9.25
# 10                      Chips and Guacamole   4.45
# 11                     Chicken Crispy Tacos   8.75
# 12                       Chicken Soft Tacos   8.75
# 13                             Chicken Bowl  11.25
# 14                      Chips and Guacamole   4.45
# 15    Chips and Tomatillo-Green Chili Salsa   2.39
# 16                          Chicken Burrito   8.49
# ...

# %%
dff[dff.item_name == "Veggie Salad Bowl"]['item_price'].sum()
# Out:
# 182.5

# %%
a = dff[dff.item_name == "Veggie Salad Bowl"]['item_price'].value_counts
a.sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-0b3a1e7ec139> in <module>()
# ----> 1 a = dff[dff.item_name == "Veggie Salad Bowl"]['item_price'].value_counts
#       2 a.sum()
#
# NameError: name 'dff' is not defined

# %%
import pandas as pd
dr = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv')
dr.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
dr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
# country                         193 non-null object
# beer_servings                   193 non-null int64
# spirit_servings                 193 non-null int64
# wine_servings                   193 non-null int64
# total_litres_of_pure_alcohol    193 non-null float64
# continent                       170 non-null object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.1+ KB

# %%
a = dr.groupby(by = 'continent').beer_servings.mean()
a
# Out:
# continent
# AF     61.471698
# AS     37.045455
# EU    193.777778
# OC     89.687500
# SA    175.083333
# Name: beer_servings, dtype: float64

# %%
dr.groupby(by = 'continent').wine_servings.describe()
# Out:
#            count        mean        std  min   25%    50%     75%    max
# continent
# AF          53.0   16.264151  38.846419  0.0   1.0    2.0   13.00  233.0
# AS          44.0    9.068182  21.667034  0.0   0.0    1.0    8.00  123.0
# EU          45.0  142.222222  97.421738  0.0  59.0  128.0  195.00  370.0
# OC          16.0   35.625000  64.555790  0.0   1.0    8.5   23.25  212.0
# SA          12.0   62.416667  88.620189  1.0   3.0   12.0   98.50  221.0

# %%
import pandas as pd
dr = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv')
dr.head()
# Out:
#    Year  Population    Total  Violent  Property  Murder  Forcible_Rape  \
# 0  1960   179323175  3384200   288460   3095700    9110          17190
# 1  1961   182992000  3488000   289390   3198600    8740          17220
# 2  1962   185771000  3752200   301510   3450700    8530          17550
# 3  1963   188483000  4109500   316970   3792500    8640          17650
# 4  1964   191141000  4564600   364220   4200400    9360          21420
#
#    Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 0   107840              154320    912100        1855400         328200
# 1   106670              156760    949600        1913000         336000
# 2   110860              164570    994300        2089600         366800
# 3   116470              174210   1086400        2297800         408300
# 4   130390              203050   1213200        2514400         472800

# %%
dr['Year'] = pd.to_datetime(dr['Year'],format='%Y')
#dr.set_index('Year',inplace=True)
#dr.info()
dr
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Year'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-99-75042482f6e3> in <module>()
# ...

# %%
dr1 = dr.groupby('Year').sum()
dr1
# Out:
#             Population     Total  Violent  Property  Murder  Forcible_Rape  \
# Year
# 1960-01-01   179323175   3384200   288460   3095700    9110          17190
# 1961-01-01   182992000   3488000   289390   3198600    8740          17220
# 1962-01-01   185771000   3752200   301510   3450700    8530          17550
# 1963-01-01   188483000   4109500   316970   3792500    8640          17650
# 1964-01-01   191141000   4564600   364220   4200400    9360          21420
# 1965-01-01   193526000   4739400   387390   4352000    9960          23410
# 1966-01-01   195576000   5223500   430180   4793300   11040          25820
# 1967-01-01   197457000   5903400   499930   5403500   12240          27620
# 1968-01-01   199399000   6720200   595010   6125200   13800          31670
# 1969-01-01   201385000   7410900   661870   6749000   14760          37170
# 1970-01-01   203235298   8098000   738820   7359200   16000          37990
# ...

# %%
dr = dr.resample('10AS').sum()
dr
# Out:
#             Population      Total   Violent   Property  Murder  Forcible_Rape  \
# Year
# 1960-01-01  1915053175   49295900   4134930   45160900  106180         236720
# 1970-01-01  2121193298  100991600   9607930   91383800  192230         554570
# 1980-01-01  2371370069  131123369  14074328  117048900  206439         865639
# 1990-01-01  2612825258  136582146  17527048  119053499  211664         998827
# 2000-01-01  2947969117  115012044  13968056  100944369  163068         922499
# 2010-01-01  1570146307   50167967   6072017   44095950   72867         421059
# 2020-01-01           0          0         0          0       0              0
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1960-01-01  1633510             2158520  13321100       26547700
# 1970-01-01  4159020             4702120  28486000       53157800
# 1980-01-01  5383109             7619130  33073494       72040253
# 1990-01-01  5748930            10568963  26750015       77679366
# ...

# %%
pop = dr.Population.resample('10AS').max()
dr['Population'] = pop
dr
# Out:
#             Population      Total   Violent   Property  Murder  Forcible_Rape  \
# Year
# 1960-01-01  1915053175   49295900   4134930   45160900  106180         236720
# 1970-01-01  2121193298  100991600   9607930   91383800  192230         554570
# 1980-01-01  2371370069  131123369  14074328  117048900  206439         865639
# 1990-01-01  2612825258  136582146  17527048  119053499  211664         998827
# 2000-01-01  2947969117  115012044  13968056  100944369  163068         922499
# 2010-01-01  1570146307   50167967   6072017   44095950   72867         421059
# 2020-01-01           0          0         0          0       0              0
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1960-01-01  1633510             2158520  13321100       26547700
# 1970-01-01  4159020             4702120  28486000       53157800
# 1980-01-01  5383109             7619130  33073494       72040253
# 1990-01-01  5748930            10568963  26750015       77679366
# ...

# %%
dr.iloc[0:3]
# Out:
#             Population      Total   Violent   Property  Murder  Forcible_Rape  \
# Year
# 1960-01-01  1915053175   49295900   4134930   45160900  106180         236720
# 1970-01-01  2121193298  100991600   9607930   91383800  192230         554570
# 1980-01-01  2371370069  131123369  14074328  117048900  206439         865639
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1960-01-01  1633510             2158520  13321100       26547700
# 1970-01-01  4159020             4702120  28486000       53157800
# 1980-01-01  5383109             7619130  33073494       72040253
#
#             Vehicle_Theft
# Year
# 1960-01-01        5292100
# 1970-01-01        9739900
# 1980-01-01       11935411

# %%
dr.loc[ dr.index[[3,4,6]],['Murder','Robbery']]
# Out:
#             Murder  Robbery
# Year
# 1990-01-01  211664  5748930
# 2000-01-01  163068  4230366
# 2020-01-01       0        0

# %%
dr
# Out:
#             Population      Total   Violent   Property  Murder  Forcible_Rape  \
# Year
# 1960-01-01  1915053175   49295900   4134930   45160900  106180         236720
# 1970-01-01  2121193298  100991600   9607930   91383800  192230         554570
# 1980-01-01  2371370069  131123369  14074328  117048900  206439         865639
# 1990-01-01  2612825258  136582146  17527048  119053499  211664         998827
# 2000-01-01  2947969117  115012044  13968056  100944369  163068         922499
# 2010-01-01  1570146307   50167967   6072017   44095950   72867         421059
# 2020-01-01           0          0         0          0       0              0
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1960-01-01  1633510             2158520  13321100       26547700
# 1970-01-01  4159020             4702120  28486000       53157800
# 1980-01-01  5383109             7619130  33073494       72040253
# 1990-01-01  5748930            10568963  26750015       77679366
# ...

# %%
dr[(dr['Murder'] <= 211664) & (dr['Murder'] >= 72867)]
# Out:
#             Population      Total   Violent   Property  Murder  Forcible_Rape  \
# Year
# 1960-01-01  1915053175   49295900   4134930   45160900  106180         236720
# 1970-01-01  2121193298  100991600   9607930   91383800  192230         554570
# 1980-01-01  2371370069  131123369  14074328  117048900  206439         865639
# 1990-01-01  2612825258  136582146  17527048  119053499  211664         998827
# 2000-01-01  2947969117  115012044  13968056  100944369  163068         922499
# 2010-01-01  1570146307   50167967   6072017   44095950   72867         421059
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1960-01-01  1633510             2158520  13321100       26547700
# 1970-01-01  4159020             4702120  28486000       53157800
# 1980-01-01  5383109             7619130  33073494       72040253
# 1990-01-01  5748930            10568963  26750015       77679366
# 2000-01-01  4230366             8652124  21565176       67970291
# ...

# %%
dr.sort_values('Murder',ascending=False)
# Out:
#             Population      Total   Violent   Property  Murder  Forcible_Rape  \
# Year
# 1990-01-01  2612825258  136582146  17527048  119053499  211664         998827
# 1980-01-01  2371370069  131123369  14074328  117048900  206439         865639
# 1970-01-01  2121193298  100991600   9607930   91383800  192230         554570
# 2000-01-01  2947969117  115012044  13968056  100944369  163068         922499
# 1960-01-01  1915053175   49295900   4134930   45160900  106180         236720
# 2010-01-01  1570146307   50167967   6072017   44095950   72867         421059
# 2020-01-01           0          0         0          0       0              0
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1990-01-01  5748930            10568963  26750015       77679366
# 1980-01-01  5383109             7619130  33073494       72040253
# 1970-01-01  4159020             4702120  28486000       53157800
# 2000-01-01  4230366             8652124  21565176       67970291
# ...

# %%
dr.sort_values(by = ['Murder','Violent'],ascending=[False,True])
# Out:
#             Population      Total   Violent   Property  Murder  Forcible_Rape  \
# Year
# 1990-01-01  2612825258  136582146  17527048  119053499  211664         998827
# 1980-01-01  2371370069  131123369  14074328  117048900  206439         865639
# 1970-01-01  2121193298  100991600   9607930   91383800  192230         554570
# 2000-01-01  2947969117  115012044  13968056  100944369  163068         922499
# 1960-01-01  1915053175   49295900   4134930   45160900  106180         236720
# 2010-01-01  1570146307   50167967   6072017   44095950   72867         421059
# 2020-01-01           0          0         0          0       0              0
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1990-01-01  5748930            10568963  26750015       77679366
# 1980-01-01  5383109             7619130  33073494       72040253
# 1970-01-01  4159020             4702120  28486000       53157800
# 2000-01-01  4230366             8652124  21565176       67970291
# ...

# %%
dr
# Out:
#             Population      Total   Violent   Property  Murder  Forcible_Rape  \
# Year
# 1960-01-01  1915053175   49295900   4134930   45160900  106180         236720
# 1970-01-01  2121193298  100991600   9607930   91383800  192230         554570
# 1980-01-01  2371370069  131123369  14074328  117048900  206439         865639
# 1990-01-01  2612825258  136582146  17527048  119053499  211664         998827
# 2000-01-01  2947969117  115012044  13968056  100944369  163068         922499
# 2010-01-01  1570146307   50167967   6072017   44095950   72867         421059
# 2020-01-01           0          0         0          0       0              0
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1960-01-01  1633510             2158520  13321100       26547700
# 1970-01-01  4159020             4702120  28486000       53157800
# 1980-01-01  5383109             7619130  33073494       72040253
# 1990-01-01  5748930            10568963  26750015       77679366
# ...
