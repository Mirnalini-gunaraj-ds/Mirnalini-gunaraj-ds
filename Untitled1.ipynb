# %%
X = {1,2,3,4}

# %%
X = set([9,9,9,9,9,'nine',8,7,6,5,4,3,2,1])

# %%
X
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9, 'nine'}

# %%
y = {'z','l','f','a'}

# %%
y
# Out:
# {'a', 'f', 'l', 'z'}

# %%
y[0] = 'b'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-957e6108138a> in <module>()
# ----> 1 y[0] = 'b'
#
# TypeError: 'set' object does not support item assignment

# %%
y.add('b')

# %%
y
# Out:
# {'a', 'b', 'f', 'l', 'z'}

# %%
y.add('l')

# %%
y
# Out:
# {'a', 'b', 'f', 'l', 'z'}

# %%
d = {'a':1 ,'b':2,'c':1,'d':{'a':4}}

# %%
d['a']
# Out:
# 1

# %%
for i in d:
    print(i,d[i])
# Out:
# a 1
# b 2
# c 1
# d {'a': 4}

# %%
d.keys()
# Out:
# dict_keys(['a', 'b', 'c', 'd'])

# %%
e ={'zz':{'yy':{'xx':'val'}}}

# %%
e['zz']['yy']['xx']
# Out:
# 'val'

# %%
 e.items()
# Out:
# dict_items([('zz', {'yy': {'xx': 'val'}})])

# %%
{x:x*2 for x in range(10)}
# Out:
# {0: 0, 1: 2, 2: 4, 3: 6, 4: 8, 5: 10, 6: 12, 7: 14, 8: 16, 9: 18}

# %%
l = [5,7,4,3,32,7,3]
[i for i in l if (i % 2) == 0]
# Out:
# [4, 32]

# %%
l = ['mirna','harshi','alagi']
[l[x] for x in range(0,3) if len(l[x]) == 5]
# Out:
# ['mirna', 'alagi']

# %%
name = input()
type(name)
# Out:
# 1
# str
