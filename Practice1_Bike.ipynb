# %%
import pandas as pd
train = pd.read_csv(r'C:\\Users\\Mirnalini\train_bikes.csv',parse_dates=['datetime'])

# %%
train.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
train.datetime = pd.to_datetime(train.datetime)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
# datetime      10886 non-null datetime64[ns]
# season        10886 non-null int64
# holiday       10886 non-null int64
# workingday    10886 non-null int64
# weather       10886 non-null int64
# temp          10886 non-null float64
# atemp         10886 non-null float64
# humidity      10886 non-null int64
# windspeed     10886 non-null float64
# casual        10886 non-null int64
# registered    10886 non-null int64
# count         10886 non-null int64
# dtypes: datetime64[ns](1), float64(3), int64(8)
# memory usage: 1020.6 KB

# %%
train.isnull().sum()
# Out:
# datetime      0
# season        0
# holiday       0
# workingday    0
# weather       0
# temp          0
# atemp         0
# humidity      0
# windspeed     0
# casual        0
# registered    0
# count         0
# dtype: int64

# %%
test = pd.read_csv(r'C:\\Users\\Mirnalini\test_bikes.csv')
test.head()
# Out:
#               datetime  season  holiday  workingday  weather   temp   atemp  \
# 0  2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 1  2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2  2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 3  2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 4  2011-01-20 04:00:00       1        0           1        1  10.66  12.880
#
#    humidity  windspeed
# 0        56    26.0027
# 1        56     0.0000
# 2        56     0.0000
# 3        56    11.0014
# 4        56    11.0014

# %%
test.datetime = pd.to_datetime(test.datetime)

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6493 entries, 0 to 6492
# Data columns (total 9 columns):
# datetime      6493 non-null datetime64[ns]
# season        6493 non-null int64
# holiday       6493 non-null int64
# workingday    6493 non-null int64
# weather       6493 non-null int64
# temp          6493 non-null float64
# atemp         6493 non-null float64
# humidity      6493 non-null int64
# windspeed     6493 non-null float64
# dtypes: datetime64[ns](1), float64(3), int64(5)
# memory usage: 456.6 KB

# %%
train.describe()
# Out:
#              season       holiday    workingday       weather         temp  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.00000
# mean       2.506614      0.028569      0.680875      1.418427     20.23086
# std        1.116174      0.166599      0.466159      0.633839      7.79159
# min        1.000000      0.000000      0.000000      1.000000      0.82000
# 25%        2.000000      0.000000      0.000000      1.000000     13.94000
# 50%        3.000000      0.000000      1.000000      1.000000     20.50000
# 75%        4.000000      0.000000      1.000000      2.000000     26.24000
# max        4.000000      1.000000      1.000000      4.000000     41.00000
#
#               atemp      humidity     windspeed        casual    registered  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.000000
# mean      23.655084     61.886460     12.799395     36.021955    155.552177
# ...

# %%
test.describe()
# Out:
#             season      holiday   workingday      weather         temp  \
# count  6493.000000  6493.000000  6493.000000  6493.000000  6493.000000
# mean      2.493300     0.029108     0.685815     1.436778    20.620607
# std       1.091258     0.168123     0.464226     0.648390     8.059583
# min       1.000000     0.000000     0.000000     1.000000     0.820000
# 25%       2.000000     0.000000     0.000000     1.000000    13.940000
# 50%       3.000000     0.000000     1.000000     1.000000    21.320000
# 75%       3.000000     0.000000     1.000000     2.000000    27.060000
# max       4.000000     1.000000     1.000000     4.000000    40.180000
#
#              atemp     humidity    windspeed
# count  6493.000000  6493.000000  6493.000000
# mean     24.012865    64.125212    12.631157
# std       8.782741    19.293391     8.250151
# min       0.000000    16.000000     0.000000
# 25%      16.665000    49.000000     7.001500
# 50%      25.000000    65.000000    11.001400
# ...

# %%
train.sample(5)
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 1721  2011-04-17 15:00:00       2        0           0        1  22.14
# 5813  2012-01-17 10:00:00       1        0           1        3  12.30
# 3     2011-01-01 03:00:00       1        0           0        1   9.84
# 10772 2012-12-15 06:00:00       4        0           0        2   9.84
# 1470  2011-04-07 03:00:00       2        0           1        1  14.76
#
#         atemp  humidity  windspeed  casual  registered  count
# 1721   25.760        32    35.0008   179.0       209.0    388
# 5813   14.395        87    16.9979     1.0        61.0     62
# 3      14.395        75     0.0000     3.0        10.0     13
# 10772  14.395        75     0.0000     NaN        11.0     11
# 1470   17.425        66    12.9980     NaN         3.0      3

# %%
import seaborn as sns
sns.countplot(x='season', data=train,hue='holiday')

# %%
sns.distplot(train['count'],bins=10)
# Out:
# C:\Users\Mirnalini\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
b = train['count'].sort_values(ascending=True).head()

# %%
aa = train['count'].nonzero()
bb = train['count'].iloc[aa]
aa
# Out:
# (array([    0,     1,     2, ..., 10883, 10884, 10885], dtype=int64),)

# %%
train['count'].value_counts().sort_values(ascending=False).head()
# Out:
# 5    169
# 4    149
# 3    144
# 6    135
# 2    132
# Name: count, dtype: int64

# %%
train['count'].loc[train['count']==0].count()
# Out:
# 0

# %%
train['casual'].loc[train['casual']==0].count()
# Out:
# 986

# %%
train['registered'].loc[train['registered']==0].count()
train['registered'] = train['registered'].replace(0,np.nan)
train['registered'].loc[train['registered']==0].count()
# Out:
# 0

# %%
import numpy as np
train['casual'] = train['casual'].replace(0,np.nan)
train['casual'].loc[train['casual']==0].count()
# Out:
# 0

# %%
sns.heatmap(train.isnull())

# %%
import seaborn as sns

import matplotlib.pyplot as plt
plt.figure(figsize=(15,5))
sns.countplot(x='casual', data=train,hue='season')

# %%
plt.figure(figsize=(20,5))
sns.boxplot(x='casual', data=train,hue='season',color='red')

# %%
import missingno as msno
msno.matrix(train)

# %%
from pandas_profiling import ProfileReport
a = ProfileReport(test.sample(n=100))
a.to_file(output_file='new.html')

# %%
train['datetime']
# Out:
# 0       2011-01-01 00:00:00
# 1       2011-01-01 01:00:00
# 2       2011-01-01 02:00:00
# 3       2011-01-01 03:00:00
# 4       2011-01-01 04:00:00
#                 ...
# 10881   2012-12-19 19:00:00
# 10882   2012-12-19 20:00:00
# 10883   2012-12-19 21:00:00
# 10884   2012-12-19 22:00:00
# 10885   2012-12-19 23:00:00
# Name: datetime, Length: 10886, dtype: datetime64[ns]

# %%
dd = train

# %%
dd.loc [:,('hour')] = dd.datetime.dt.hour

# %%
dd
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 0     2011-01-01 00:00:00       1        0           0        1   9.84
# 1     2011-01-01 01:00:00       1        0           0        1   9.02
# 2     2011-01-01 02:00:00       1        0           0        1   9.02
# 3     2011-01-01 03:00:00       1        0           0        1   9.84
# 4     2011-01-01 04:00:00       1        0           0        1   9.84
# ...                   ...     ...      ...         ...      ...    ...
# 10881 2012-12-19 19:00:00       4        0           1        1  15.58
# 10882 2012-12-19 20:00:00       4        0           1        1  14.76
# 10883 2012-12-19 21:00:00       4        0           1        1  13.94
# 10884 2012-12-19 22:00:00       4        0           1        1  13.94
# 10885 2012-12-19 23:00:00       4        0           1        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count  hour
# ...

# %%
dd.hour
# Out:
# 0         0
# 1         1
# 2         2
# 3         3
# 4         4
#          ..
# 10881    19
# 10882    20
# 10883    21
# 10884    22
# 10885    23
# Name: hour, Length: 10886, dtype: int64
